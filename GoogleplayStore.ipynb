# %%
## Import the all library

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
## fetch the dataset into apps variable.

# %%
apps = pd.read_csv("googleplaystore.csv")

# %%
## check the dataset information 
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
##show the top 5 dataset from apps
apps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
## Check the total Ratings count 
apps.Rating.value_counts()
# Out:
# 4.4     1109
# 4.3     1076
# 4.5     1038
# 4.2      952
# 4.6      823
# 4.1      708
# 4.0      568
# 4.7      499
# 3.9      386
# 3.8      303
# 5.0      274
# 3.7      239
# 4.8      234
# 3.6      174
# 3.5      163
# 3.4      128
# 3.3      102
# 4.9       87
# 3.0       83
# 3.1       69
# 3.2       64
# 2.9       45
# 2.8       42
# 2.6       25
# 2.7       25
# 2.5       21
# 2.3       20
# 2.4       19
# 1.0       16
# 2.2       14
# 1.9       13
# 2.0       12
# 2.1        8
# 1.7        8
# 1.8        8
# 1.6        4
# 1.4        3
# 1.5        3
# 1.2        1
# 19.0       1
# Name: Rating, dtype: int64

# %%
## we can't rate 19.0 in google play store , we need to remove this ratings

# %%
apps[apps.Rating ==19.0]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
## drop the index 10472 and check other index

# %%
apps = apps.drop(apps.index[10472])
apps.iloc[10471:10475]
# Out:
#                            App         Category  Rating Reviews  Size  \
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
# 10475         Wi-Fi Visualizer            TOOLS     3.9     132  2.6M
#
#           Installs  Type Price Content Rating           Genres  \
# 10471     100,000+  Free     0       Everyone  Personalization
# 10473  10,000,000+  Free     0       Everyone            Tools
# 10474       1,000+  Free     0       Everyone    Communication
# 10475      50,000+  Free     0       Everyone            Tools
#
#             Last Updated Current Ver   Android Ver
# 10471     August 5, 2014       3.0.0  4.0.3 and up
# 10473     August 7, 2018     6.06.14    4.4 and up
# 10474  November 21, 2014     2.2.1.5    2.2 and up
# 10475       May 17, 2017       0.0.9    2.3 and up

# %%
## remove all NA from dataset
apps= apps.dropna()

# %%
## Check apps info 
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
# App               9360 non-null object
# Category          9360 non-null object
# Rating            9360 non-null float64
# Reviews           9360 non-null object
# Size              9360 non-null object
# Installs          9360 non-null object
# Type              9360 non-null object
# Price             9360 non-null object
# Content Rating    9360 non-null object
# Genres            9360 non-null object
# Last Updated      9360 non-null object
# Current Ver       9360 non-null object
# Android Ver       9360 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1023.8+ KB

# %%
##berfor cleaning dataset there is 10841 dataset and after cleaning overall dataset there is 9360 dataset. we clean almost 1476 data

# %%
apps.Category.nunique()
# Out:
# 33

# %%
apps.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
apps.Genres.nunique()
# Out:
# 115

# %%
apps.Genres.unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Auto & Vehicles', 'Beauty',
#        'Books & Reference', 'Business', 'Comics', 'Comics;Creativity',
#        'Communication', 'Dating', 'Education;Education', 'Education',
#        'Education;Creativity', 'Education;Music & Video',
#        'Education;Action & Adventure', 'Education;Pretend Play',
#        'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
#        'Casual;Action & Adventure', 'Simulation', 'Adventure', 'Board',
# ...

# %%
##We will be using seaborn's boxplot to visualize the correlation. As we bind x-axis as applications grouped by their categories, and y-axis as average ratings of the categories; then we'll be able to see clearly whether there is a strong relation between the category of application and its rating or not.

# %%
## I created a dataframe which consist of two featurs
## Category (category_list)
## Ratings AVG(ratings)

# %%
category_list = list(apps.Category.unique())
ratings = []

for category in category_list:
    x = apps[apps.Category == category]
    rating_rate = x.Rating.sum()/len(x)
    ratings.append(rating_rate)
data = pd.DataFrame({'Category':category_list, 'Rating':ratings})
new_index = (data['Rating'].sort_values(ascending=False)).index.values
sorted_data = data.reindex(new_index)

sorted_data
# Out:
#                Category    Rating
# 10               EVENTS  4.435556
# 8             EDUCATION  4.389032
# 0        ART_AND_DESIGN  4.377049
# 3   BOOKS_AND_REFERENCE  4.346067
# 26      PERSONALIZATION  4.335256
# 28            PARENTING  4.300000
# 17                 GAME  4.286326
# 2                BEAUTY  4.278571
# 13   HEALTH_AND_FITNESS  4.277104
# 21             SHOPPING  4.259664
# 20               SOCIAL  4.255598
# 29              WEATHER  4.244000
# 23               SPORTS  4.223511
# 27         PRODUCTIVITY  4.211396
# 14       HOUSE_AND_HOME  4.197368
# 18               FAMILY  4.192383
# 22          PHOTOGRAPHY  4.192114
# 1     AUTO_AND_VEHICLES  4.190411
# 19              MEDICAL  4.189143
# 15   LIBRARIES_AND_DEMO  4.179688
# 12       FOOD_AND_DRINK  4.166972
# 6         COMMUNICATION  4.158537
# 5                COMICS  4.155172
# 31   NEWS_AND_MAGAZINES  4.132189
# 11              FINANCE  4.131889
# 9         ENTERTAINMENT  4.126174
# ...

# %%
sorted_data.tail()
# Out:
#                Category    Rating
# 16            LIFESTYLE  4.094904
# 30        VIDEO_PLAYERS  4.063750
# 32  MAPS_AND_NAVIGATION  4.051613
# 25                TOOLS  4.047203
# 7                DATING  3.970769

# %%
import matplotlib as mpl
import seaborn as sns
plt.style.use('seaborn-notebook')
plt.figure(figsize=(20,10))
sns.barplot(x=sorted_data.Category, y=sorted_data.Rating)

ha = {'center': 'center', 'right': 'left', 'left': 'right'}
offset = {'center': 0.5, 'right': 0.57, 'left': 0.43}  # x_txt = x + w*off

plt.xticks(rotation = 60)
plt.xlabel('Application Category',fontweight='bold',fontsize= 20,)
plt.ylim(3.5,4.5)
plt.ylabel('Ratings',fontweight='bold', fontsize= 20)
plt.suptitle('Average Ratings by Category', fontweight='bold',fontsize='30', color='green')
plt.show()

# %%
apps["Content Rating"].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %% [raw]
# Another feature named content rating, which is the age group the app is targeted at. I wonder how it distributes over the categories, so I will be using seaborn's horizontal barplot to visualize it.

# %%
# list of categories
cat_list = list(apps.Category.unique())

# content rating lists
everyone = []
teen = []
everyone_10 = []
mature_17 = []
adults_only_18 = []
unrated = []

# the function which fills category's (temp) content rating counts into lists
def insert_counts(everyone, teen, everyone_10, mature_17, adults_only_18, unrated, temp):
    
    # everyone
    try:
        everyone.append(temp.groupby('Content Rating').size()['Everyone'])
    except:
        everyone.append(0)
    
    # teen
    try:
        teen.append(temp.groupby('Content Rating').size()['Teen'])
    except:
        teen.append(0)
    
    # everyone 10+
    try:
        everyone_10.append(temp.groupby('Content Rating').size()['Everyone 10+'])
    except:
        everyone_10.append(0)
        
    # mature 17+
    try:
        mature_17.append(temp.groupby('Content Rating').size()['Mature 17+'])
    except:
        mature_17.append(0)
        
    # adults only 18+
    try:
        adults_only_18.append(temp.groupby('Content Rating').size()['Adults only 18+'])
    except:
        adults_only_18.append(0)
        
    # unrated
    try:
        unrated.append(temp.groupby('Content Rating').size()['Unrated'])
    except:
        unrated.append(0)

# fill lists iteratively via function
for cat in cat_list:
    temp = apps[apps.Category == cat]
    insert_counts(everyone, teen, everyone_10, mature_17, adults_only_18, unrated, temp)

# %%
f,ax = plt.subplots(figsize = (25,25))
sns.barplot(x=everyone,y=cat_list,color='green',alpha = 0.5,label='Everyone')
sns.barplot(x=teen,y=cat_list,color='blue',alpha = 0.7,label='Teen')
sns.barplot(x=everyone_10,y=cat_list,color='pink',alpha = 0.6,label='Everyone 10+')
sns.barplot(x=mature_17,y=cat_list,color='yellow',alpha = 0.6,label='Mature 17+')
sns.barplot(x=adults_only_18,y=cat_list,color='red',alpha = 0.6,label='Adults Only 18+')
sns.barplot(x=unrated,y=cat_list,color='aqua',alpha = 0.6,label='Unrated')

ax.legend(loc='upper right',frameon = True)
ax.set(xlabel='Percentage of Content Ratings', ylabel='Categories',title = "Percentage of Categories According to Content Ratings")
# Out:
# [Text(0,0.5,'Categories'),
#  Text(0.5,0,'Percentage of Content Ratings'),
#  Text(0.5,1,'Percentage of Categories According to Content Ratings')]

# %%
apps2 = apps
apps2['Android Ver'].value_counts()
# Out:
# 4.1 and up            2059
# Varies with device    1319
# 4.0.3 and up          1240
# 4.0 and up            1129
# 4.4 and up             875
# 2.3 and up             582
# 5.0 and up             535
# 4.2 and up             337
# 2.3.3 and up           240
# 3.0 and up             211
# 2.2 and up             208
# 4.3 and up             207
# 2.1 and up             113
# 1.6 and up              87
# 6.0 and up              48
# 7.0 and up              41
# 3.2 and up              31
# 2.0 and up              27
# 5.1 and up              18
# 1.5 and up              15
# 3.1 and up               8
# 2.0.1 and up             7
# 4.4W and up              6
# 8.0 and up               5
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 1.0 and up               2
# 5.0 - 8.0                2
# 5.0 - 6.0                1
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
apps2['Android Ver'][apps2['Android Ver'] == 'Varies with device'] = '4.1 and up'

apps2['android_ver_int'] = apps2['Android Ver'].str[0:1].astype(int)

apps2['android_ver_int'].value_counts()
# Out:
# 4    7175
# 2    1177
# 5     556
# 3     250
# 1     104
# 6      48
# 7      45
# 8       5
# Name: android_ver_int, dtype: int64

# %%
list_1 = ['Category','Content Rating','Android Ver']

# %%
def bar_plot(x,y,y_label,x_label,title,color,ax):
    # plt.figure(figsize=(10,5))
    bar = sns.barplot(x = x,y=y,ax=ax,orient='h')
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    plt.title(title)
    for i, v in enumerate(x.values):
        ax.text(v + 3, i + .25, str(v), color='black', fontweight='bold')
    return bar

# %%
fig = plt.figure(figsize=(14,18))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
i = 1
for names in list_1 :
    ax1 = fig.add_subplot(2, 2, i)
    df2 = apps[names].value_counts()
    df2 = df2.reset_index()
    bar_plot(x = df2[names],y = df2['index'],y_label = 'Freq',title = 'Bar Chart On {}'.format(names),color='red',ax=ax1,x_label=names)
    i += 1

# %%
List_ver = ['Content Rating']

# %%
def bar_plot(x,y,y_label,x_label,title,color,ax=None):
    plt.figure(figsize=(5,8))
    bar = sns.barplot(x = x,y=y,orient='h')
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    plt.title(title)
    for i, v in enumerate(x.values):
        bar.text(v + 3, i + .25, str(v), color='black', fontweight='bold')
    return bar
df2 = apps['Content Rating'].value_counts()
df2 = df2.reset_index()
df2 = df2[df2['Content Rating'] > 100]
bar_plot(x = df2['Content Rating'],y = df2['index'],y_label = 'Freq',title = 'Bar Chart On Content Rating',color='red',x_label='Gerner')

# %%
Cat_Rating = list(df2['index'][0:10])

# %%
d = pd.DatetimeIndex(apps['Last Updated'])
apps['year'] = d.year
apps['month'] = d.month

# %%
for i in Cat_Rating:
    ##ay = apps[(apps['Content Rating']== i) &(apps['Android Ver']=

    play = apps[(apps['Content Rating']== i) & (apps['Rating'] >=4.5)& (apps['year'] == 2018)]['App']
    print('')
                                            
    print('printing 10 Apps with Rating >= 4.5 and  and Year = 2018 in {}'.format(i))
    print('--------------------------------------------------')
    print(play[0:10])
# Out:
# printing 10 Apps with Rating >= 4.5 and  and Year = 2018 in Everyone
# --------------------------------------------------
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...
# 9                         Kids Paint Free - Drawing Fun
# 13                                Mandala Coloring Book
# 16         Photo Designer - Write your name with shapes
# 19                                         ibis Paint X
# 24                          HD Mickey Minnie Wallpapers
# 25                           Harley Quinn wallpapers HD
# 32                            Anime Manga Coloring Book
# 36       UNICORN - Color By Number & Pixel Art Coloring
# 41                         Sad Poetry Photo Frames 2018
# Name: App, dtype: object
#
# printing 10 Apps with Rating >= 4.5 and  and Year = 2018 in Teen
# --------------------------------------------------
# 3                                  Sketch - Draw & Paint
# 34                                       I Creative Idea
# ...

# %%
 for i in Cat_Rating:

    play = apps[(apps['Content Rating']== i) & (apps['Rating'] >=4.5)& (apps['year'] == 2018)]['App']
    print('')
                                            
    print('printing 10 Apps with Rating >= 4.5 and  and Year = 2018 in {}'.format(i))
    print('--------------------------------------------------')
    print(play[0:10])
# Out:
# printing 10 Apps with Rating >= 4.5 and  and Year = 2018 in Everyone
# --------------------------------------------------
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...
# 9                         Kids Paint Free - Drawing Fun
# 13                                Mandala Coloring Book
# 16         Photo Designer - Write your name with shapes
# 19                                         ibis Paint X
# 24                          HD Mickey Minnie Wallpapers
# 25                           Harley Quinn wallpapers HD
# 32                            Anime Manga Coloring Book
# 36       UNICORN - Color By Number & Pixel Art Coloring
# 41                         Sad Poetry Photo Frames 2018
# Name: App, dtype: object
#
# printing 10 Apps with Rating >= 4.5 and  and Year = 2018 in Teen
# --------------------------------------------------
# 3                                  Sketch - Draw & Paint
# 34                                       I Creative Idea
# ...

# %%
for i in Cat_Rating:
    
    play = apps[(apps['Android Ver'] != '4.1 +') & (apps['Content Rating']== i) & (apps['year'] == 2018)]['App']
    print('')
    print('Printing 10 Apps with Android Ver 4.1 + and Rating >= 4.5 and Year = 2018 in {}'.format(i))
    print('--------------------------------------------------')
    print(play[0:10])
# Out:
# Printing 10 Apps with Android Ver 4.1 + and Rating >= 4.5 and Year = 2018 in Everyone
# --------------------------------------------------
# 0        Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                   Coloring book moana
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...
# 4                 Pixel Draw - Number Art Coloring Book
# 6               Smoke Effect Photo Maker - Smoke Editor
# 7                                      Infinite Painter
# 9                         Kids Paint Free - Drawing Fun
# 11              Name Art Photo Editor - Focus n Filters
# 13                                Mandala Coloring Book
# 14      3D Color Pixel by Number - Sandbox Art Coloring
# Name: App, dtype: object
#
# Printing 10 Apps with Android Ver 4.1 + and Rating >= 4.5 and Year = 2018 in Teen
# --------------------------------------------------
# 3                              Sketch - Draw & Paint
# 12                    Tattoo Name On My Photo Editor
# ...

# %%
for i in Cat_Rating:
    
    play = apps[(apps['Android Ver'] != '4.1 +') & (apps['Content Rating']== i) & (apps['year'] == 2017)]['App']
    print('')
    print('Printing 10 Apps with Android Ver 4.1 + and Rating >= 4.5 and Year = 2017 in {}'.format(i))
    print('--------------------------------------------------')
    print(play[0:10])
# Out:
# Printing 10 Apps with Android Ver 4.1 + and Rating >= 4.5 and Year = 2017 in Everyone
# --------------------------------------------------
# 5                            Paper flowers instructions
# 8                                  Garden Coloring Book
# 10                              Text on Photo - Fonteee
# 17                             350 Diy Room Decor Ideas
# 26                        Colorfit - Drawing & Coloring
# 29                      Easy Realistic Drawing Tutorial
# 38                       PIP Camera - PIP Collage Maker
# 46    Install images with music to make video withou...
# 47                Little Teddy Bear Colouring Book Game
# 99                       ipsy: Makeup, Beauty, and Tips
# Name: App, dtype: object
#
# Printing 10 Apps with Android Ver 4.1 + and Rating >= 4.5 and Year = 2017 in Teen
# --------------------------------------------------
# 528                                    Adult Dirty Emojis
# ...

# %%
for i in Cat_Rating:
    
    play = apps[(apps['Android Ver'] != '4.1 +') & (apps['Content Rating']== i) & (apps['year'] == 2016)]['App']
    print('')
    print('Printing 10 Apps with Android Ver 4.1 + and Year = 2016 in {}'.format(i))
    print('--------------------------------------------------')
    print(play[0:10])
# Out:
# Printing 10 Apps with Android Ver 4.1 + and Year = 2016 in Everyone
# --------------------------------------------------
# 66                   Used Cars Mexico
# 102        Mirror - Zoom & Exposure -
# 176                  Free Book Reader
# 200                      SuperLivePro
# 361                      Xperia Link™
# 424      DU Browser—Browse fast & fun
# 450                       Caller ID +
# 470    Vonage Mobile® Call Video Text
# 726      Game for KIDS: KIDS match'em
# 752                 Quiz&Learn Python
# Name: App, dtype: object
#
# Printing 10 Apps with Android Ver 4.1 + and Year = 2016 in Teen
# --------------------------------------------------
# 377                         Omlet Chat
# 1837    Call of Duty:Black Ops Zombies
# 3778                              Digg
# 4131           RPG End of Aspiration F
# 4613      Please, Don't Touch Anything
# 4616    Please Don't Touch Anything 3D
# 4806                     Gangster Town
# 4829            Cube Z (Pixel Zombies)
# ...

# %%
list_1 = ['Category', 'Installs', 'Type']

# %%
def bar_plot(x,y,y_label,x_label,title,color,ax):
    # plt.figure(figsize=(10,5))
    bar = sns.barplot(x = x,y=y,ax=ax,orient='h')
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    plt.title(title)
    for i, v in enumerate(x.values):
        ax.text(v + 3, i + .25, str(v), color='black', fontweight='bold')
    return bar

# %%
fig = plt.figure(figsize=(14,18))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
i = 1
for names in list_1:
    ax1 = fig.add_subplot(2, 2, i)
    df2 = apps[names].value_counts()
    df2 = df2.reset_index()
    bar_plot(x = df2[names],y = df2['index'],y_label = 'Freq',title = 'Bar Chart On {}'.format(names),color='red',ax=ax1,x_label=names)
    i += 1

# %%
list_2 = ['Genres']

# %%
def bar_plot(x,y,y_label,x_label,title,color,ax=None):
    plt.figure(figsize=(5,8))
    bar = sns.barplot(x = x,y=y,orient='h')
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    plt.title(title)
    for i, v in enumerate(x.values):
        bar.text(v + 3, i + .25, str(v), color='black', fontweight='bold')
    return bar
df2 = apps['Genres'].value_counts()
df2 = df2.reset_index()
df2 = df2[df2['Genres'] > 100]
bar_plot(x = df2['Genres'],y = df2['index'],y_label = 'Freq',title = 'Bar Chart On Gerner',color='red',x_label='Gerner')

# %%
Genres=  list(df2['index'][0:10])

# %%
d = pd.DatetimeIndex(apps['Last Updated'])
apps['year'] = d.year
apps['month'] = d.month

# %%
for i in Genres:
    
    play = apps[(apps['Installs'] != '1,000,000,000+') & (apps['Genres'] == i) & (apps['Rating'] >= 4.5) & (apps['year'] == 2018)]['App']
    print('')
    print('Printing 10 Apps with 100 million installs and Rating >= 4.5 and Year = 2018 in {}'.format(i))
    print('--------------------------------------------------')
    print(play[0:10])
# Out:
# Printing 10 Apps with 100 million installs and Rating >= 4.5 and Year = 2018 in Tools
# --------------------------------------------------
# 3239    Cache Cleaner-DU Speed Booster (booster & clea...
# 3240                                   Moto Suggestions ™
# 3246                                         File Manager
# 3248    Calculator - free calculator, multi calculator...
# 3249                                  ASUS Sound Recorder
# 3253                                           ZenUI Help
# 3255                           SHAREit - Transfer & Share
# 3256                        ZenUI Keyboard – Emoji, Theme
# 3257      Files Go by Google: Free up space on your phone
# 3285                         I Can't Wake Up! Alarm Clock
# Name: App, dtype: object
#
# Printing 10 Apps with 100 million installs and Rating >= 4.5 and Year = 2018 in Entertainment
# --------------------------------------------------
# 876                     ivi - movies and TV shows in HD
# ...

# %%
import pickle
selfref_list = [1,2,3]
selfref_list.append(selfref_list)
output = open('Genr.pkl','rb')

# %%
# avg app size
size = apps[apps['Size'] != 'Varies with device']
size_m = []
size_n = []
for i in size['Size']:
    size_m.append(i[-1])
    size_n.append(float(i[0:-1]))
    
size['size_m'] = size_m
size['size_n'] = size_n
size['size_m'] = size['size_m'].replace('k',1000)
size['size_m'] = size['size_m'].replace('M',1000000)
# Out:
# C:\Users\Bhabuk Pokharel\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Bhabuk Pokharel\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Bhabuk Pokharel\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# avg app size
size['bites'] = size['size_n'] * size['size_m']
grouped = size.groupby('Category').agg({'bites': [min, max]})
grouped.columns = grouped.columns.droplevel(level=0)
grouped.rename(columns={"min": "min_size", "max": "max_size"})
grouped.head(10)

# %%
size.groupby('Category')['bites'].mean().head(35)

# %%
objects = []
with (open("Genr.pkl", "rb")) as openfile:
    while True:
        try:
            objects.append(pickle.load(openfile))
        except EOFError:
            break

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-678a75876153> in <module>()
# ----> 1 objects.head()
#
# AttributeError: 'list' object has no attribute 'head'
